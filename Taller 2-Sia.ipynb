# %% [markdown]
# #### TALLER N° 2 - SIA
# ### Integrantes:
# * Matías Figueroa
# * Victor Muñoz
# * Danny Torres

# %%
import pandas as pd
url='https://raw.githubusercontent.com/MFigueroa-A/Taller2-SIA/main/TotalesNacionales_covid.csv'
df_covid=pd.read_csv(url,sep=';')
df_covid
# Out:
#           Fecha  Casos nuevos con sintomas  Casos totales  Casos recuperados  \
# 0    2020-03-02                          1              1                0.0
# 1    2020-03-03                          0              1                0.0
# 2    2020-03-04                          2              3                0.0
# 3    2020-03-05                          1              4                0.0
# 4    2020-03-06                          1              5                0.0
# ..          ...                        ...            ...                ...
# 300  2020-12-27                       1105         600105                NaN
# 301  2020-12-28                       1395         602028                NaN
# 302  2020-12-29                       1410         603986                NaN
# 303  2020-12-30                       1554         605950                NaN
# 304  2020-12-31                       2036         608973                NaN
#
# ...

# %% [markdown]
# ### INTERPRETACIÓN:

# %%
# obtenemos los datos estadísticos como el percentil, la media y el estándar de los valores numéricos de la serie o el marco de datos.
df_covid.describe()
# Out:
#        Casos nuevos con sintomas  Casos totales  Casos recuperados  \
# count                 305.000000     305.000000          92.000000
# mean                 1471.422951  300560.167213        8647.413043
# std                  1244.551862  211770.802092       11519.219916
# min                     0.000000       1.000000           0.000000
# 25%                   824.000000   43781.000000          20.750000
# 50%                  1133.000000  357658.000000        3460.000000
# 75%                  1551.000000  488190.000000       12778.250000
# max                  6368.000000  608973.000000       44946.000000
#
#          Fallecidos  Casos activos  Casos nuevos sin sintomas  \
# count    305.000000     286.000000                 247.000000
# mean    7886.796721   14328.475524                 443.218623
# std     6096.138438   10374.260260                 138.988421
# min        0.000000       1.000000                  56.000000
# ...

# %% [markdown]
# ### INTERPRETACIÓN:

# %%
# obtenemos el tipo de indice y las columnas, los valores no nulos y el uso de memoria.
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Fecha                                  305 non-null    object
#  1   Casos nuevos con sintomas              305 non-null    int64
#  2   Casos totales                          305 non-null    int64
#  3   Casos recuperados                      92 non-null     float64
#  4   Fallecidos                             305 non-null    int64
#  5   Casos activos                          286 non-null    float64
#  6   Casos nuevos sin sintomas              247 non-null    float64
#  7   Casos nuevos totales                   305 non-null    int64
#  8   Casos activos por FD                   305 non-null    int64
#  9   Casos activos por FIS                  194 non-null    float64
# ...

# %%
#obtenemos el numero de muestras de datos (en este caso las filas) y las caracteristicas (features)en las columnas
df_covid.shape
# Out:
# (305, 20)

# %%
df_covid.head(15)
# Out:
#          Fecha  Casos nuevos con sintomas  Casos totales  Casos recuperados  \
# 0   2020-03-02                          1              1                0.0
# 1   2020-03-03                          0              1                0.0
# 2   2020-03-04                          2              3                0.0
# 3   2020-03-05                          1              4                0.0
# 4   2020-03-06                          1              5                0.0
# 5   2020-03-07                          2              7                0.0
# 6   2020-03-08                          3             10                0.0
# 7   2020-03-09                          5             15                0.0
# 8   2020-03-10                          2             17                0.0
# 9   2020-03-11                          6             23                0.0
# 10  2020-03-12                         10             33                0.0
# ...

# %%
df_covid.isna().any()
# Out:
# Fecha                                    False
# Casos nuevos con sintomas                False
# Casos totales                            False
# Casos recuperados                         True
# Fallecidos                               False
# Casos activos                             True
# Casos nuevos sin sintomas                 True
# Casos nuevos totales                     False
# Casos activos por FD                     False
# Casos activos por FIS                     True
# Casos recuperados por FIS                 True
# Casos recuperados por FD                 False
# Casos confirmados recuperados             True
# Casos activos confirmados                 True
# Casos probables acumulados                True
# Casos activos probables                   True
# Casos nuevos sin notificar                True
# Casos confirmados por antigeno            True
# Casos con sospecha de reinfeccion         True
# Casos nuevos confirmados por antigeno     True
# dtype: bool

# %%
pd.pivot_table(df_sports, index=['Product','Gender'],
               columns=['MaritalStatus'], aggfunc=['mean'])
# Out:
#                      mean                                             \
#                       Age             Education              Fitness
# MaritalStatus   Partnered     Single  Partnered     Single Partnered
# Product Gender
# TM195   Female  28.333333  28.692308  14.888889  15.538462  2.851852
#         Male    31.380952  25.631579  15.428571  14.473684  2.857143
# TM498   Female  30.000000  28.142857  15.200000  15.214286  2.933333
#         Male    30.380952  25.200000  15.285714  14.500000  2.904762
# TM798   Female  29.000000  24.333333  17.500000  18.333333  5.000000
#         Male    30.000000  28.928571  17.421053  16.928571  4.631579
#
#                                                                               \
#                                 Income                     Miles
# MaritalStatus     Single     Partnered        Single   Partnered      Single
# Product Gender
# TM195   Female  2.923077  46153.777778  45742.384615   74.925926   78.846154
# ...

# %%
# obtenemos la media (promedio) de los valores de la muestra.
df_sports['Age'].mean()
# Out:
# 28.788888888888888

# %%
# obtenemos la mediana (valor central) de los valores de la muestra.
df_sports['Income'].median()
# Out:
# 50596.5

# %%
# obtenemos la desviación estándar de la muestra.
df_sports['Age'].std()
# Out:
# 6.943498135399795

# %%
# Requerimiento N°1

# %%
# Requerimiento N°2

# %%
# Requerimiento N°3

# %%
# Requerimiento N°4

# %%
# Requerimiento N°5

# %%
# Requerimiento N°6

# %%
# Requerimiento N°7

# %%
# Requerimiento N°8

# %%
import seaborn as sns
sns.countplot(x='Product', hue='Gender',data=df_sports)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
sns.distplot(df_sports['Age'])
# Out:
# C:\Users\mathi\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
age_sports=df_sports['Age']
plt.hist(age_sports,color="blue",label="Age")
plt.title('Histograma de ', loc='left')
plt.ylabel('CANTIDAD')
plt.xlabel('EDAD') 
plt.show()

# Una vez que ejecute el codigo para generar el grafico de tipo histograma, proceda a configurarlo (titulo,labels,color,otros)

# %%
plt.bar(df_sports['Product'],df_sports["Age"])
plt.title('Histograma de ')
plt.ylabel('CANTIDAD')
plt.xlabel('PRODUCT')
plt.show()
# Una vez que ejecute ejecute el codigo para generar el grafico de tipo histograma, proceda a configurarlo (titulo,labels,color, otros)

# %% [markdown]
# #### CONCLUSIONES
